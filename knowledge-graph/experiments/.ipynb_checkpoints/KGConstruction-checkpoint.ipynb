# %%
# %matplotlib inline

import scispacy
import spacy
from spacy.lang.en import English
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from spacy import displacy
from pprint import pprint
from nltk.stem import WordNetLemmatizer 
from pathlib import Path
import json
import sys
sys.path.append("..")
from helpers import printGraph, reformat, json_to_kg, kg_to_json
from KGConstruction import getSentences, appendChunk, process, kg_from_ner, combine_2_ner_files

# %%
# Load NER pretrained models
med7 = spacy.load("en_core_med7_lg")
sci = spacy.load("en_core_sci_md")
sci2 = spacy.load("en_ner_bc5cdr_md")

# %%
# Load dataframe
df = pd.read_csv("../data/2020-09-26/metadata.csv")
# Out:
# FileNotFoundErrorTraceback (most recent call last)
# <ipython-input-3-af78e4193abf> in <module>
#       1 # Load dataframe
# ----> 2 df = pd.read_csv("../data/2020-09-26/metadata.csv")
#
# /opt/conda/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ...

# %%
from spacy.gold import GoldParse

# ---------------------------------------------------------------------
# This block is making a knowledge graph while also doing NER manually
# ---------------------------------------------------------------------
knowledgeGraph = nx.Graph()
model = sci
graph_file = "kg_results/graph.json"

# Retrieve abstracts
abstracts_list = df['abstract'].to_list()

# Process each individual abstract
for abstract in abstracts_list[:1]:
    process(abstract)
printGraph(knowledgeGraph)

# Test loading to json file and reading it back out
# (if the two graphs that print out look the same, we're in business)
kg_to_json(knowledgeGraph, graph_file)
kg2 = json_to_kg(graph_file)
printGraph(kg2)

# %%
ner_file = "ner_test.txt"
kg = kg_from_ner(ner_file)
# Display knowledge graph
printGraph(kg)

# %%
# Testing the above combine function
ner_file1 = "med7_test.txt"
ner_file2 = "scispacy_test.txt"
output_file = "combined_test.txt"
combine_2_ner_files(ner_file1, ner_file2, output_file)
kg = kg_from_ner(output_file)
printGraph(kg)
